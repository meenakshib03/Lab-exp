# %%
import numpy as np
import pandas as pd

# %%
data_set=pd.read_excel(r'C:\clg\4 DPFE MEENAKSHI\OneDrive\Desktop\billionaires.xlsx')

# %%
data_set.head()
# Out:
#              name  rank  year  company.founded        company.name  \
# 0      Bill Gates     1  1996             1975           Microsoft
# 1      Bill Gates     1  2001             1975           Microsoft
# 2      Bill Gates     1  2014             1975           Microsoft
# 3  Warren Buffett     2  1996             1962  Berkshire Hathaway
# 4  Warren Buffett     2  2001             1962  Berkshire Hathaway
#
#   company.relationship company.sector company.type  demographics.age  \
# 0              founder       Software          new                40
# 1              founder       Software          new                45
# 2              founder       Software          new                58
# 3              founder        Finance          new                65
# 4              founder        Finance          new                70
#
#   demographics.gender  ...    location.gdp location.region  \
# 0                male  ...   8100000000000   North America
# ...

# %%
data_set.columns
# Out:
# Index(['name', 'rank', 'year', 'company.founded', 'company.name',
#        'company.relationship', 'company.sector', 'company.type',
#        'demographics.age', 'demographics.gender', 'location.citizenship',
#        'location.country code', 'location.gdp', 'location.region',
#        'wealth.type', 'wealth.worth in billions', 'wealth.how.category',
#        'wealth.how.from emerging', 'wealth.how.industry',
#        'wealth.how.inherited', 'wealth.how.was founder',
#        'wealth.how.was political'],
#       dtype='object')

# %%
data_set.isnull()
# Out:
#        name   rank   year  company.founded  company.name  \
# 0     False  False  False            False         False
# 1     False  False  False            False         False
# 2     False  False  False            False         False
# 3     False  False  False            False         False
# 4     False  False  False            False         False
# ...     ...    ...    ...              ...           ...
# 2609  False  False  False            False         False
# 2610  False  False  False            False         False
# 2611  False  False  False            False         False
# 2612  False  False  False            False         False
# 2613  False  False  False            False         False
#
#       company.relationship  company.sector  company.type  demographics.age  \
# 0                    False           False         False             False
# 1                    False           False         False             False
# ...

# %%
data_set.isnull().sum()
# Out:
# name                         0
# rank                         0
# year                         0
# company.founded              0
# company.name                38
# company.relationship        46
# company.sector              23
# company.type                36
# demographics.age             0
# demographics.gender         34
# location.citizenship         0
# location.country code        0
# location.gdp                 0
# location.region              0
# wealth.type                 22
# wealth.worth in billions     0
# wealth.how.category          1
# wealth.how.from emerging     0
# wealth.how.industry          1
# wealth.how.inherited         0
# wealth.how.was founder       0
# wealth.how.was political     0
# dtype: int64

# %%
type(data_set)
# Out:
# pandas.core.frame.DataFrame

# %%
data_set['year'].unique()
# Out:
# array([1996, 2001, 2014], dtype=int64)

# %%
data_set['year'].nunique()
# Out:
# 3

# %%
data_set.dropna()
# Out:
#                 name  rank  year  company.founded  \
# 0         Bill Gates     1  1996             1975
# 1         Bill Gates     1  2001             1975
# 2         Bill Gates     1  2014             1975
# 3     Warren Buffett     2  1996             1962
# 4     Warren Buffett     2  2001             1962
# ...              ...   ...   ...              ...
# 2609     Wu Chung-Yi  1565  2014             1991
# 2610        Wu Xiong  1565  2014             1999
# 2611       Yang Keng  1565  2014                0
# 2612   Zdenek Bakala  1565  2014             1994
# 2613     Zhu Wenchen  1565  2014             1999
#
#                          company.name company.relationship  \
# 0                           Microsoft              founder
# 1                           Microsoft              founder
# 2                           Microsoft              founder
# 3                  Berkshire Hathaway              founder
# 4                  Berkshire Hathaway              founder
# ...

# %%
data_set.head()
# Out:
#              name  rank  year  company.founded        company.name  \
# 0      Bill Gates     1  1996             1975           Microsoft
# 1      Bill Gates     1  2001             1975           Microsoft
# 2      Bill Gates     1  2014             1975           Microsoft
# 3  Warren Buffett     2  1996             1962  Berkshire Hathaway
# 4  Warren Buffett     2  2001             1962  Berkshire Hathaway
#
#   company.relationship company.sector company.type  demographics.age  \
# 0              founder       Software          new                40
# 1              founder       Software          new                45
# 2              founder       Software          new                58
# 3              founder        Finance          new                65
# 4              founder        Finance          new                70
#
#   demographics.gender  ...    location.gdp location.region  \
# 0                male  ...   8100000000000   North America
# ...

# %%
data_set.dropna(thresh=3)
# Out:
#                 name  rank  year  company.founded  \
# 0         Bill Gates     1  1996             1975
# 1         Bill Gates     1  2001             1975
# 2         Bill Gates     1  2014             1975
# 3     Warren Buffett     2  1996             1962
# 4     Warren Buffett     2  2001             1962
# ...              ...   ...   ...              ...
# 2609     Wu Chung-Yi  1565  2014             1991
# 2610        Wu Xiong  1565  2014             1999
# 2611       Yang Keng  1565  2014                0
# 2612   Zdenek Bakala  1565  2014             1994
# 2613     Zhu Wenchen  1565  2014             1999
#
#                          company.name company.relationship  \
# 0                           Microsoft              founder
# 1                           Microsoft              founder
# 2                           Microsoft              founder
# 3                  Berkshire Hathaway              founder
# 4                  Berkshire Hathaway              founder
# ...

# %%
data_set.dropna(axis=1)
# Out:
#                 name  rank  year  company.founded  demographics.age  \
# 0         Bill Gates     1  1996             1975                40
# 1         Bill Gates     1  2001             1975                45
# 2         Bill Gates     1  2014             1975                58
# 3     Warren Buffett     2  1996             1962                65
# 4     Warren Buffett     2  2001             1962                70
# ...              ...   ...   ...              ...               ...
# 2609     Wu Chung-Yi  1565  2014             1991                55
# 2610        Wu Xiong  1565  2014             1999                 0
# 2611       Yang Keng  1565  2014                0                53
# 2612   Zdenek Bakala  1565  2014             1994                53
# 2613     Zhu Wenchen  1565  2014             1999                48
#
#      location.citizenship location.country code    location.gdp  \
# 0           United States                   USA   8100000000000
# ...

# %%
data_set
# Out:
#                 name  rank  year  company.founded  \
# 0         Bill Gates     1  1996             1975
# 1         Bill Gates     1  2001             1975
# 2         Bill Gates     1  2014             1975
# 3     Warren Buffett     2  1996             1962
# 4     Warren Buffett     2  2001             1962
# ...              ...   ...   ...              ...
# 2609     Wu Chung-Yi  1565  2014             1991
# 2610        Wu Xiong  1565  2014             1999
# 2611       Yang Keng  1565  2014                0
# 2612   Zdenek Bakala  1565  2014             1994
# 2613     Zhu Wenchen  1565  2014             1999
#
#                          company.name company.relationship  \
# 0                           Microsoft              founder
# 1                           Microsoft              founder
# 2                           Microsoft              founder
# 3                  Berkshire Hathaway              founder
# 4                  Berkshire Hathaway              founder
# ...

# %%
data_set.dropna(thresh=2)
# Out:
#                 name  rank  year  company.founded  \
# 0         Bill Gates     1  1996             1975
# 1         Bill Gates     1  2001             1975
# 2         Bill Gates     1  2014             1975
# 3     Warren Buffett     2  1996             1962
# 4     Warren Buffett     2  2001             1962
# ...              ...   ...   ...              ...
# 2609     Wu Chung-Yi  1565  2014             1991
# 2610        Wu Xiong  1565  2014             1999
# 2611       Yang Keng  1565  2014                0
# 2612   Zdenek Bakala  1565  2014             1994
# 2613     Zhu Wenchen  1565  2014             1999
#
#                          company.name company.relationship  \
# 0                           Microsoft              founder
# 1                           Microsoft              founder
# 2                           Microsoft              founder
# 3                  Berkshire Hathaway              founder
# 4                  Berkshire Hathaway              founder
# ...
