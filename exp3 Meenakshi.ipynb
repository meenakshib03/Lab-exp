# %% [markdown]
# # EXPERIMENT 3

# %%
import numpy as np
import pandas as pd
data_set=pd.read_excel(r'CC:\clg\4 DPFE MEENAKSHI\OneDrive\Desktop\billionaires.xlsx')

# %%
data_set.fillna(value=100)
# Out:
#                 name  rank  year  company.founded  \
# 0         Bill Gates     1  1996             1975
# 1         Bill Gates     1  2001             1975
# 2         Bill Gates     1  2014             1975
# 3     Warren Buffett     2  1996             1962
# 4     Warren Buffett     2  2001             1962
# ...              ...   ...   ...              ...
# 2609     Wu Chung-Yi  1565  2014             1991
# 2610        Wu Xiong  1565  2014             1999
# 2611       Yang Keng  1565  2014                0
# 2612   Zdenek Bakala  1565  2014             1994
# 2613     Zhu Wenchen  1565  2014             1999
#
#                          company.name company.relationship  \
# 0                           Microsoft              founder
# 1                           Microsoft              founder
# 2                           Microsoft              founder
# 3                  Berkshire Hathaway              founder
# 4                  Berkshire Hathaway              founder
# ...

# %%
data_set['year'].fillna(value=2000)
# Out:
# 0       1996
# 1       2001
# 2       2014
# 3       1996
# 4       2001
#         ...
# 2609    2014
# 2610    2014
# 2611    2014
# 2612    2014
# 2613    2014
# Name: year, Length: 2614, dtype: int64

# %%
m=data_set['year'].mode()

# %%
m
# Out:
# 0    2014
# Name: year, dtype: int64

# %%
data_set.fillna(value=m[0])#setting  mean as missing value
# Out:
#                 name  rank  year  company.founded  \
# 0         Bill Gates     1  1996             1975
# 1         Bill Gates     1  2001             1975
# 2         Bill Gates     1  2014             1975
# 3     Warren Buffett     2  1996             1962
# 4     Warren Buffett     2  2001             1962
# ...              ...   ...   ...              ...
# 2609     Wu Chung-Yi  1565  2014             1991
# 2610        Wu Xiong  1565  2014             1999
# 2611       Yang Keng  1565  2014                0
# 2612   Zdenek Bakala  1565  2014             1994
# 2613     Zhu Wenchen  1565  2014             1999
#
#                          company.name company.relationship  \
# 0                           Microsoft              founder
# 1                           Microsoft              founder
# 2                           Microsoft              founder
# 3                  Berkshire Hathaway              founder
# 4                  Berkshire Hathaway              founder
# ...

# %%
data_set.drop([2,5,7])
# Out:
#                          name  rank  year  company.founded  \
# 0                  Bill Gates     1  1996             1975
# 1                  Bill Gates     1  2001             1975
# 3              Warren Buffett     2  1996             1962
# 4              Warren Buffett     2  2001             1962
# 6     Oeri Hoffman and Sacher     3  1996             1896
# ...                       ...   ...   ...              ...
# 2609              Wu Chung-Yi  1565  2014             1991
# 2610                 Wu Xiong  1565  2014             1999
# 2611                Yang Keng  1565  2014                0
# 2612            Zdenek Bakala  1565  2014             1994
# 2613              Zhu Wenchen  1565  2014             1999
#
#                          company.name company.relationship  \
# 0                           Microsoft              founder
# 1                           Microsoft              founder
# 3                  Berkshire Hathaway              founder
# ...

# %%
data_set.drop(['rank','year'],axis=1)
# Out:
#                 name  company.founded                     company.name  \
# 0         Bill Gates             1975                        Microsoft
# 1         Bill Gates             1975                        Microsoft
# 2         Bill Gates             1975                        Microsoft
# 3     Warren Buffett             1962               Berkshire Hathaway
# 4     Warren Buffett             1962               Berkshire Hathaway
# ...              ...              ...                              ...
# 2609     Wu Chung-Yi             1991                           Tingyi
# 2610        Wu Xiong             1999  Biostime International Holdings
# 2611       Yang Keng                0                    Blue Ray Corp
# 2612   Zdenek Bakala             1994                   Patria Finance
# 2613     Zhu Wenchen             1999       Furen Pharmaceutical Group
#
#      company.relationship      company.sector company.type  demographics.age  \
# ...

# %%
m=data_set['name'].mode()

# %%
m
# Out:
# 0                 Abigail Johnson
# 1         Abilio dos Santos Diniz
# 2                      Akira Mori
# 3                Alain Wertheimer
# 4      Alberto Bailleres Gonzalez
#                   ...
# 129            Thaksin Shinawatra
# 130            Thomas Schmidheiny
# 131               Tiong Hiew King
# 132                Warren Buffett
# 133                   Wee Cho Yaw
# Name: name, Length: 134, dtype: object

# %%
data_set['name'].fillna(m)
# Out:
# 0           Bill Gates
# 1           Bill Gates
# 2           Bill Gates
# 3       Warren Buffett
# 4       Warren Buffett
#              ...
# 2609       Wu Chung-Yi
# 2610          Wu Xiong
# 2611         Yang Keng
# 2612     Zdenek Bakala
# 2613       Zhu Wenchen
# Name: name, Length: 2614, dtype: object

# %%
data_set
# Out:
#                 name  rank  year  company.founded  \
# 0         Bill Gates     1  1996             1975
# 1         Bill Gates     1  2001             1975
# 2         Bill Gates     1  2014             1975
# 3     Warren Buffett     2  1996             1962
# 4     Warren Buffett     2  2001             1962
# ...              ...   ...   ...              ...
# 2609     Wu Chung-Yi  1565  2014             1991
# 2610        Wu Xiong  1565  2014             1999
# 2611       Yang Keng  1565  2014                0
# 2612   Zdenek Bakala  1565  2014             1994
# 2613     Zhu Wenchen  1565  2014             1999
#
#                          company.name company.relationship  \
# 0                           Microsoft              founder
# 1                           Microsoft              founder
# 2                           Microsoft              founder
# 3                  Berkshire Hathaway              founder
# 4                  Berkshire Hathaway              founder
# ...
